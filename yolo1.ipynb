# %% [markdown]
# <a href="https://colab.research.google.com/github/sheeshagar-iqbal/AW_sales/blob/main/yolo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# mv: cannot stat 'kaggle.json': No such file or directory

# %%
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia
# Out:
# Dataset URL: https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia
# License(s): other
# ^C

# %%
# Unzip the downloaded file
import zipfile
import os

zip_file_name = '/content/chest-xray-pneumonia.zip'

if os.path.exists(zip_file_name):
    with zipfile.ZipFile(zip_file_name, 'r') as zip_ref:
        zip_ref.extractall('./chest-xray-pneumonia_data')
    print(f"'{zip_file_name}' unzipped to './chest-xray-pneumonia_data/'")
else:
    print(f"Error: '{zip_file_name}' not found. Please ensure the dataset was downloaded correctly.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1669931435.py in <cell line: 0>()
#       7 if os.path.exists(zip_file_name):
#       8     with zipfile.ZipFile(zip_file_name, 'r') as zip_ref:
# ----> 9         zip_ref.extractall('./chest-xray-pneumonia_data')
#      10     print(f"'{zip_file_name}' unzipped to './chest-xray-pneumonia_data/'")
#      11 else:
#
# /usr/lib/python3.12/zipfile/__init__.py in extractall(self, path, members, pwd)
#    1768
#    1769         for zipinfo in members:
# -> 1770             self._extract_member(zipinfo, path, pwd)
#    1771
#    1772     @classmethod
#
# /usr/lib/python3.12/zipfile/__init__.py in _extract_member(self, member, targetpath, pwd)
#    1826         with self.open(member, pwd=pwd) as source, \
#    1827              open(targetpath, "wb") as target:
# -> 1828             shutil.copyfileobj(source, target)
# ...

# %%
# List the extracted files to identify the CSV file
# !ls ./ambulance_data
# Out:
# ls: cannot access './ambulance_data': No such file or directory

# %% [markdown]
# # **cheast xray classification**

# %%
model = YOLO("yolov8n-cls.pt")

# %%
model.train(data="/content/chest-xray-pneumonia_data/chest_xray/chest_xray", epochs=5)
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model= YOLO('/content/runs/classify/train/weights/best.pt')

# %%
result=model('/content/sample_data/test/NORMAL/IM-0001-0001.jpeg')
result[0].show()
# Out:
# image 1/1 /content/sample_data/test/NORMAL/IM-0001-0001.jpeg: 224x224 NORMAL 1.00, PNEUMONIA 0.00, 2.8ms
# Speed: 19.3ms preprocess, 2.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# <PIL.Image.Image image mode=RGB size=1857x1317>

# %%
result=model('/content/sample_data/test/PNEUMONIA/person100_bacteria_479.jpeg')
result[0].show()
# Out:
# image 1/1 /content/sample_data/test/PNEUMONIA/person100_bacteria_479.jpeg: 224x224 PNEUMONIA 1.00, NORMAL 0.00, 3.0ms
# Speed: 5.8ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# <PIL.Image.Image image mode=RGB size=904x552>

# %%
# !pip install yolo
# import yolo

# %%
# !pip install ultralytics
from ultralytics import YOLO

# %%
import sys
print("Python version:", sys.version)

# %%
import torch
print("PyTorch version:", torch.__version__)

# %%
model = YOLO("yolo11n.pt")

# %%
results = model("/content/simba-8618301_1280.jpg")  # Predict on an image
results[0].show()  # Display results

# %%
results = model("/content/DSC.JPG")  # Predict on an image
results[0].show()  # Display results
# /content/DSC_3682.JPG
